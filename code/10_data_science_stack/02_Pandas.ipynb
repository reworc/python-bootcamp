# %%
import pandas as pd

df = pd.read_csv("../data/astronauts.csv", delimiter=',')

# %%
df["Name"]
# Out:
# 0            Joseph M. Acaba
# 1             Loren W. Acton
# 2           James C. Adamson
# 3            Thomas D. Akers
# 4                Buzz Aldrin
#                ...
# 352            David A. Wolf
# 353    Neil W. Woodward III
# 354         Alfred M. Worden
# 355            John W. Young
# 356          George D. Zamka
# Name: Name, Length: 357, dtype: object

# %%
for name in df["Name"]:
    print(name)
# Out:
# Joseph M. Acaba
# Loren W. Acton
# James C. Adamson
# Thomas D. Akers
# Buzz Aldrin
# Andrew M. Allen
# Joseph P. Allen
# Scott D. Altman
# William A. Anders
# Clayton C. Anderson
# Michael P. Anderson
# Dominic A. Antonelli
# Jerome Apt III
# Lee J. Archambault
# Neil A. Armstrong
# Richard R. Arnold II
# Jeffrey S. Ashby
# Serena M. Aunon
# James P. Bagian
# Ellen S. Baker
# Michael A. Baker
# Michael R. Barratt
# Daniel T. Barry
# John-David F. Bartoe
# Charles A. Bassett II
# Alan L. Bean
# Robert L. Behnken
# John E. Blaha
# Michael J. Bloomfield
# Guion S. Bluford Jr.
# Karol J. Bobko
# Eric A. Boe
# Charles F. Bolden Jr.
# Frank Borman
# Stephen G. Bowen
# Kenneth D. Bowersox
# Charles E. Brady Jr.
# Vance D. Brand
# Daniel C. Brandenstein
# Randolph J. Bresnik
# Roy D. Bridges Jr.
# Curtis L. Brown Jr.
# David M. Brown
# Mark N. Brown
# James F. Buchli
# Jay Clark Buckey
# John S. Bull
# Daniel C. Burbank
# Daniel W. Bursch
# Robert D. Cabana
# Yvonne D. Cagle
# ...

# %%
first = df.iloc[0]
display(first)
# Out:
# Name                                                     Joseph M. Acaba
# Year                                                              2004.0
# Group                                                               19.0
# Status                                                            Active
# Birth Date                                                     5/17/1967
# Birth Place                                                Inglewood, CA
# Gender                                                              Male
# Alma Mater             University of California-Santa Barbara; Univer...
# Undergraduate Major                                              Geology
# Graduate Major                                                   Geology
# Military Rank                                                        NaN
# Military Branch                                                      NaN
# Space Flights                                                          2
# ...

# %%
print(type(first))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(first["Birth Date"])
# Out:
# 5/17/1967

# %%
last = df[-5:]
display(last)
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 352   Indianapolis, IN   Male
# 353        Chicago, IL   Male
# 354        Jackson, MI   Male
# 355  San Francisco, CA   Male
# 356    Jersey City, NJ   Male
#
#                                             Alma Mater  \
# 352              Purdue University; Indiana University
# 353  MIT; University of Texas-Austin; George Washin...
# 354        US Military Academy; University of Michigan
# 355                    Georgia Institute of Technology
# 356  US Naval Academy; Florida Institute of Technology
#
# ...

# %%
for pos,d in df.iterrows():
    print(pos)
    print(d)
    break
# Out:
# 0
# Name                                                     Joseph M. Acaba
# Year                                                              2004.0
# Group                                                               19.0
# Status                                                            Active
# Birth Date                                                     5/17/1967
# Birth Place                                                Inglewood, CA
# Gender                                                              Male
# Alma Mater             University of California-Santa Barbara; Univer...
# Undergraduate Major                                              Geology
# Graduate Major                                                   Geology
# Military Rank                                                        NaN
# Military Branch                                                      NaN
# Space Flights                                                          2
# ...

# %%
filtered = df[df["Year"] < 1990]
display(filtered)
# Out:
#                          Name    Year  Group    Status  Birth Date  \
# 2            James C. Adamson  1984.0   10.0   Retired    3/3/1946
# 3             Thomas D. Akers  1987.0   12.0   Retired   5/20/1951
# 4                 Buzz Aldrin  1963.0    3.0   Retired   1/20/1930
# 5             Andrew M. Allen  1987.0   12.0   Retired    8/4/1955
# 6             Joseph P. Allen  1967.0    6.0   Retired   6/27/1937
# ..                        ...     ...    ...       ...         ...
# 341       Edward H. White II   1962.0    2.0  Deceased  11/14/1930
# 344  Clifton C. Williams Jr.   1963.0    3.0  Deceased   9/26/1932
# 345        Donald E. Williams  1978.0    8.0   Retired   2/13/1958
# 354          Alfred M. Worden  1966.0    5.0   Retired    2/7/1932
# 355             John W. Young  1962.0    2.0   Retired   9/24/1930
#
#              Birth Place Gender                                   Alma Mater  \
# 2             Warsaw, NY   Male    US Military Academy; Princeton University
# ...

# %%
deaths = df[df["Death Mission"].isnull() == False]
display(deaths)
# Out:
#                      Name    Year  Group    Status  Birth Date  \
# 10    Michael P. Anderson  1995.0   15.0  Deceased  12/25/1959
# 42         David M. Brown  1996.0   16.0  Deceased   4/16/1956
# 63       Roger B. Chaffee  1963.0    3.0  Deceased   2/15/1935
# 67         Kalpana Chawla  1995.0   15.0  Deceased    6/1/1961
# 70        Laurel B. Clark  1996.0   16.0  Deceased   3/10/1961
# 140     Virgil I. Grissom  1959.0    1.0  Deceased    4/3/1926
# 170       Rick D. Husband  1995.0   15.0  Deceased   7/12/1957
# 173     Gregory B. Jarvis     NaN    NaN  Deceased   8/24/1944
# 219  S. Christa McAuliffe     NaN    NaN  Deceased    9/2/1948
# 222     William C. McCool  1996.0   16.0  Deceased   9/23/1961
# 226      Ronald E. McNair  1978.0    8.0  Deceased  10/21/1950
# 250    Ellison S. Onizuka  1978.0    8.0  Deceased   6/24/1946
# 271      Judith A. Resnik  1978.0    8.0  Deceased    4/5/1949
# 287     Francis R. Scobee  1978.0    8.0  Deceased   5/19/1939
# ...

# %%
dead_after_1990 = df[(df["Year"] > 1990) & (df["Death Mission"].isnull() == False)]
display(dead_after_1990)
# Out:
#                     Name    Year  Group    Status  Birth Date  \
# 10   Michael P. Anderson  1995.0   15.0  Deceased  12/25/1959
# 42        David M. Brown  1996.0   16.0  Deceased   4/16/1956
# 67        Kalpana Chawla  1995.0   15.0  Deceased    6/1/1961
# 70       Laurel B. Clark  1996.0   16.0  Deceased   3/10/1961
# 170      Rick D. Husband  1995.0   15.0  Deceased   7/12/1957
# 222    William C. McCool  1996.0   16.0  Deceased   9/23/1961
#
#          Birth Place  Gender  \
# 10   Plattsburgh, NY    Male
# 42     Arlington, VA    Male
# 67     Karnal, India  Female
# 70          Ames, IA  Female
# 170     Amarillo, TX    Male
# 222    San Diego, CA    Male
#
#                                             Alma Mater  \
# 10      University of Washington; Creighton University
# 42   College of William & Mary; Eastern Virginia Me...
# 67   Punjab Engineering College; University of Texa...
# 70                     University of Wisconsin-Madison
# ...

# %%
df.sort_values("Name", ascending=False)
# Out:
#                          Name    Year  Group      Status  Birth Date  \
# 50            Yvonne D. Cagle  1996.0   16.0  Management   4/24/1959
# 289          Winston E. Scott  1992.0   14.0     Retired    8/6/1950
# 218  William S. McArthur Jr.   1990.0    3.0  Management   7/26/1951
# 263          William R. Pogue  1966.0    5.0     Retired   1/23/1930
# 298       William M. Shepherd  1984.0   10.0     Retired   7/26/1949
# ..                        ...     ...    ...         ...         ...
# 354          Alfred M. Worden  1966.0    5.0     Retired    2/7/1932
# 282          Albert Sacco Jr.     NaN    NaN     Retired    5/3/1949
# 25               Alan L. Bean  1963.0    3.0     Retired   3/15/1932
# 264        Alan G. Poindexter  1998.0   17.0    Deceased   11/5/1961
# 297      Alan B. Shepard Jr.   1959.0    1.0    Deceased  11/18/1923
#
#         Birth Place  Gender  \
# 50   West Point, NY  Female
# 289       Miami, FL    Male
# 218  Laurinburg, NC    Male
# ...

# %% [markdown]
# # Excel + Graphics

# %%
excel_df = pd.read_excel("../data/data.xlsx")
display(excel_df)
# Out:
#     Jahr  Umsatz
# 0   2010   10000
# 1   2011    8000
# 2   2012   12000
# 3   2013   11000
# 4   2014   10000
# 5   2015    9000
# 6   2016   14000
# 7   2017   15000
# 8   2018   11500
# 9   2019   10000
# 10  2020   16000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

year = excel_df["Jahr"]
sales = excel_df["Umsatz"]

plt.plot(year, sales)
plt.show()
